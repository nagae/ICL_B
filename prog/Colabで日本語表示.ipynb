# %% [markdown]
# # Colabで日本語表示
# `matplotlib` で軸のラベルやタイトルに日本語を使おうとして
# ```python
# import matplotlib.pyplot as plt
# plt.plot([1, 2, 3, 4])
# plt.title(u"->日本語のタイトルです<-")
# plt.xlabel(u"x軸です.")
# plt.savefig('jp_font_tofu.png',dpi=100)
# plt.show()
# ```
# などとすると，下記のように日本語文字が**豆腐**になってしまう．
#
# <img alt="tofu" src="https://i.imgur.com/Z2OgSlT.png" width="300">
#
# 次のセルを実行して試してみよう．始めて実行した時には大量のエラーメッセージが出るが，コンピュータが壊れることはないので安心して実行して欲しい．

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.title(u"->日本語のタイトルです<-")
plt.xlabel(u"x軸です.")
plt.savefig('jp_font_tofu.png',dpi=100)
plt.show()
# Out:
# <ipython-input-2-5274b1533a04>:5: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   plt.savefig('jp_font_tofu.png',dpi=100)
# <ipython-input-2-5274b1533a04>:5: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from current font.
#   plt.savefig('jp_font_tofu.png',dpi=100)
# <ipython-input-2-5274b1533a04>:5: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from current font.
#   plt.savefig('jp_font_tofu.png',dpi=100)
# <ipython-input-2-5274b1533a04>:5: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   plt.savefig('jp_font_tofu.png',dpi=100)
# <ipython-input-2-5274b1533a04>:5: UserWarning: Glyph 12479 (\N{KATAKANA LETTER TA}) missing from current font.
#   plt.savefig('jp_font_tofu.png',dpi=100)
# <ipython-input-2-5274b1533a04>:5: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from current font.
#   plt.savefig('jp_font_tofu.png',dpi=100)
# ...

# %% [markdown]
# この**豆腐問題**を回避するには，[`japanize-matplotlib` モジュール](https://pypi.org/project/japanize-matplotlib/)をインストールすればいい．仮想マシンに勝手にモジュールをインストールしていいものなんだろうかとは思うが，できてしまうのだから活用しない手は無い．
#
# モジュールをインストールするためには，コードセル内で下記のコマンドを実行する．`!` というのは Python コマンドではなく，仮想マシン上の**システムコマンド**であることを意味している．`pip install` は Python のモジュールをインストールするためのコマンドである．

# %%
# !pip install japanize-matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 34.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120274 sha256=6a28ab56badd66603031c98a01022ca53fa1b88b6548dbee30c83ecc57510bbe
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize-matplotlib
# ...

# %% [markdown]
# こうしてインストールされた `japanize-matplotlib` モジュールをインポートすれば，それ以降の日本語がきれいに表示され，PDFとして保存することもできる．

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib
plt.plot([1, 2, 3, 4], label="ほげほげ")
plt.title(u"->日本語のタイトルです<-")
plt.xlabel(u"x軸です.")
plt.legend()
plt.savefig('jp_font.png',dpi=100)
plt.savefig('jp_font.pdf')
plt.show()
